# %% [markdown]
# ### YOLO v1 Architecture and Functionality
# * The input image is divided into an S × S grid of cells. Each grid cell is responsible for predicting B bounding boxes and their confidence scores, as well as C class probabilities.
#
# * The bounding box predictions include the coordinates (x, y) of the box center relative to the grid cell, the width (w) and height (h) of the box relative to the entire image, and a confidence score that indicates how certain the model is that the box contains an object.
# * Thus for each grid cell, the model predicts a total of B * 5 + C values.
# * Confidence Score = Pr(Object) * IOU(pred, truth) (It is for the bounding box)
# * Class Probabilities = Pr(Class_i | Object) (It is for the grid cell)
# * Ouput Tensor Shape = S x S x (B * 5 + C)
#
# * If a cell contains a ground-truth object (object center in cell), among the B box predictors that cell has, the one with highest IoU (with that ground truth box) is chosen as responsible. The loss is only calculated for that bounding box predictor. The other bounding box predictors in that cell are ignored for that object.
#
# * The loss function used in YOLOv1 is a combination of multiple components that measure the accuracy of the model's predictions. These components include:
#   - Localization Loss: Measures the error in the predicted bounding box coordinates (x, y, w, h) for the boxes responsible for detecting objects.
#   - Confidence Loss: Measures the error in the confidence scores for both the boxes that contain objects and those that do not.
#   - Classification Loss: Measures the error in the predicted class probabilities for the grid cells that contain objects.
#
# * During inference, the model outputs a tensor of shape S x S x (B * 5 + C) for each input image. This tensor contains the predicted bounding box coordinates, confidence scores, and class probabilities for each grid cell.
#
# * Non-Maximum Suppression (NMS) is applied to filter out overlapping bounding boxes and retain only the most confident ones for each detected object.

# %% [markdown]
# ## for Object Detection for Gate and Flare Detection

# %% [markdown]
# ### Training Code

# %%
from ultralytics import YOLO
import cv2

model = YOLO("yolov11n.pt")
MODEL_PATH = "/Users/mohammadbilal/Documents/Projects/GateDetection/Models/yolo_v11n.pt"        # path to your trained YOLO .pt file
#IMAGE_PATH = "GateDetection/assets/gate+flare-2022.jpg"       # path to input image
SAVE_PATH = "GateDetection/assets/results/output.jpg"      # output image path
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolov8n.pt to 'yolov8n.pt': 100% ━━━━━━━━━━━━ 6.2MB 21.7MB/s 0.3s.2s<0.4s8s

# %%
model.train(
    data='Dataset/data.yaml',
    save=True,
    epochs=100, 
    imgsz=480, # Resolution of the image
    batch=8, # Batch Size
    lr0=0.001,
    lrf=0.1, # Final learning rate multiplier
    momentum=0.9,
    weight_decay=0.0005,
    augment=True,
    workers=2
)

# %% [markdown]
# ### Inference Code

# %%
# For Image Inference
model = YOLO(MODEL_PATH)

results = model(
    IMAGE_PATH,
    conf=0.25,        
    iou=0.45,         
    imgsz=640,
    device="cpu"
)

annotated_img = results[0].plot()
cv2.imwrite(SAVE_PATH, annotated_img)

cv2.imshow("YOLO Detection", annotated_img)
cv2.waitKey(0)
cv2.destroyAllWindows()

print("Inference completed. Saved at:", SAVE_PATH)

# %%
# For Video Inference
import cv2
from ultralytics import YOLO

VIDEO_PATH = "/Users/mohammadbilal/Documents/Projects/GateDetection/assets/test_files/test_video3.mp4"
SAVE_PATH = "/Users/mohammadbilal/Documents/Projects/GateDetection/assets/results/output_yolo8n.mp4"

# Load model
model = YOLO(MODEL_PATH)

# Open video
cap = cv2.VideoCapture(VIDEO_PATH)
if not cap.isOpened():
    raise RuntimeError("Error opening video file")

# Get video properties
fps = cap.get(cv2.CAP_PROP_FPS)
width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

# Video writer
fourcc = cv2.VideoWriter_fourcc(*"mp4v")
out = cv2.VideoWriter(SAVE_PATH, fourcc, fps, (width, height))

while True:
    ret, frame = cap.read()
    if not ret:
        break

    # YOLO inference on frame
    results = model(
        frame,
        conf=0.25,
        iou=0.45,
        imgsz=640,
        device="cpu"
    )

    # Draw detections
    annotated_frame = results[0].plot()

    # Write frame
    out.write(annotated_frame)

    # Optional display
    cv2.imshow("YOLO Detection", annotated_frame)
    if cv2.waitKey(1) & 0xFF == ord("q"):
        break

cap.release()
out.release()
cv2.destroyAllWindows()

print("Video inference completed. Saved at:", SAVE_PATH)
# Out:
# 0: 384x640 (no detections), 30.5ms
# Speed: 1.4ms preprocess, 30.5ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 23.6ms
# Speed: 1.0ms preprocess, 23.6ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 25.0ms
# Speed: 0.9ms preprocess, 25.0ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 22.3ms
# Speed: 0.9ms preprocess, 22.3ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 31.2ms
# Speed: 1.5ms preprocess, 31.2ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 23.1ms
# Speed: 0.9ms preprocess, 23.1ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 23.9ms
# Speed: 1.0ms preprocess, 23.9ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 22.2ms
# Speed: 1.0ms preprocess, 22.2ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 23.8ms
# Speed: 0.9ms preprocess, 23.8ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 23.4ms
# Speed: 1.1ms preprocess, 23.4ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 32.3ms
# Speed: 1.1ms preprocess, 32.3ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 31.9ms
# Speed: 2.5ms preprocess, 31.9ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 26.4ms
# Speed: 1.3ms preprocess, 26.4ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 27.5ms
# Speed: 1.0ms preprocess, 27.5ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 23.0ms
# Speed: 0.9ms preprocess, 23.0ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 30.0ms
# Speed: 0.9ms preprocess, 30.0ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 22.6ms
# Speed: 0.9ms preprocess, 22.6ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 21.9ms
# Speed: 0.9ms preprocess, 21.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 23.0ms
# Speed: 0.9ms preprocess, 23.0ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 22.5ms
# Speed: 1.0ms preprocess, 22.5ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 21.3ms
# Speed: 0.9ms preprocess, 21.3ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 21.6ms
# Speed: 1.0ms preprocess, 21.6ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 21.7ms
# Speed: 0.9ms preprocess, 21.7ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 21.4ms
# Speed: 1.0ms preprocess, 21.4ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 21.2ms
# Speed: 0.9ms preprocess, 21.2ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 21.2ms
# Speed: 0.9ms preprocess, 21.2ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 22.1ms
# Speed: 1.0ms preprocess, 22.1ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 21.5ms
# Speed: 1.1ms preprocess, 21.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 22.1ms
# Speed: 0.9ms preprocess, 22.1ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 21.3ms
# Speed: 1.1ms preprocess, 21.3ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 21.4ms
# Speed: 0.9ms preprocess, 21.4ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 21.9ms
# Speed: 1.0ms preprocess, 21.9ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 21.6ms
# Speed: 1.0ms preprocess, 21.6ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 22.7ms
# Speed: 0.9ms preprocess, 22.7ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 24.7ms
# Speed: 0.9ms preprocess, 24.7ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 24.1ms
# Speed: 1.0ms preprocess, 24.1ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 24.5ms
# Speed: 1.0ms preprocess, 24.5ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Gate, 25.3ms
# Speed: 0.9ms preprocess, 25.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Gate, 21.6ms
# Speed: 1.0ms preprocess, 21.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Gate, 21.6ms
# Speed: 1.0ms preprocess, 21.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Gate, 21.6ms
# Speed: 0.9ms preprocess, 21.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Gate, 22.7ms
# Speed: 0.9ms preprocess, 22.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Gate, 22.1ms
# Speed: 0.8ms preprocess, 22.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Gate, 21.4ms
# Speed: 0.9ms preprocess, 21.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Gate, 22.4ms
# Speed: 0.9ms preprocess, 22.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Gate, 20.9ms
# Speed: 0.8ms preprocess, 20.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Gate, 21.5ms
# Speed: 0.9ms preprocess, 21.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Gate, 21.2ms
# Speed: 0.9ms preprocess, 21.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Gate, 22.0ms
# Speed: 1.0ms preprocess, 22.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Gate, 21.2ms
# Speed: 0.9ms preprocess, 21.2ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Gate, 21.5ms
# Speed: 0.9ms preprocess, 21.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Gate, 21.2ms
# Speed: 0.9ms preprocess, 21.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Gate, 21.5ms
# Speed: 0.9ms preprocess, 21.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Gate, 21.5ms
# Speed: 1.0ms preprocess, 21.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Gate, 20.7ms
# Speed: 0.9ms preprocess, 20.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Gate, 21.3ms
# Speed: 0.8ms preprocess, 21.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Gate, 21.1ms
# Speed: 0.9ms preprocess, 21.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Gate, 21.9ms
# Speed: 0.9ms preprocess, 21.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Gate, 21.5ms
# Speed: 0.9ms preprocess, 21.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Gate, 21.2ms
# Speed: 1.0ms preprocess, 21.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Gate, 21.8ms
# Speed: 1.0ms preprocess, 21.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Gate, 21.3ms
# Speed: 0.9ms preprocess, 21.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Gate, 21.0ms
# Speed: 0.8ms preprocess, 21.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Gate, 21.5ms
# Speed: 0.8ms preprocess, 21.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Gate, 22.0ms
# Speed: 0.9ms preprocess, 22.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Gate, 24.0ms
# Speed: 1.1ms preprocess, 24.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Gate, 23.4ms
# Speed: 0.8ms preprocess, 23.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Gate, 25.2ms
# Speed: 0.9ms preprocess, 25.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Gate, 24.6ms
# Speed: 1.0ms preprocess, 24.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Gate, 25.7ms
# Speed: 0.9ms preprocess, 25.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Gate, 23.6ms
# Speed: 1.0ms preprocess, 23.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Gate, 22.2ms
# Speed: 0.9ms preprocess, 22.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Gate, 24.9ms
# Speed: 1.9ms preprocess, 24.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Gate, 23.9ms
# Speed: 1.1ms preprocess, 23.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Gate, 22.6ms
# Speed: 1.0ms preprocess, 22.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Gate, 21.2ms
# Speed: 0.9ms preprocess, 21.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Gate, 24.3ms
# Speed: 0.9ms preprocess, 24.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Gate, 25.4ms
# Speed: 1.2ms preprocess, 25.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Gate, 21.7ms
# Speed: 0.8ms preprocess, 21.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Gate, 21.7ms
# Speed: 0.9ms preprocess, 21.7ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Gate, 22.5ms
# Speed: 0.9ms preprocess, 22.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Gate, 21.5ms
# Speed: 0.9ms preprocess, 21.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Gate, 21.9ms
# Speed: 0.9ms preprocess, 21.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Gate, 21.6ms
# Speed: 0.9ms preprocess, 21.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Gate, 21.3ms
# Speed: 0.9ms preprocess, 21.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Gate, 21.4ms
# Speed: 0.9ms preprocess, 21.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Gate, 21.8ms
# Speed: 0.8ms preprocess, 21.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Gate, 21.7ms
# Speed: 0.9ms preprocess, 21.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Gate, 22.9ms
# Speed: 1.1ms preprocess, 22.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Gate, 21.5ms
# Speed: 0.8ms preprocess, 21.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Gate, 21.2ms
# Speed: 0.9ms preprocess, 21.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Gate, 21.3ms
# Speed: 1.1ms preprocess, 21.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Gate, 21.1ms
# Speed: 0.8ms preprocess, 21.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Gate, 20.8ms
# Speed: 0.9ms preprocess, 20.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Gate, 21.5ms
# Speed: 0.9ms preprocess, 21.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Gate, 21.4ms
# Speed: 1.0ms preprocess, 21.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Gate, 29.1ms
# Speed: 0.9ms preprocess, 29.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Gate, 35.0ms
# Speed: 1.3ms preprocess, 35.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Gate, 41.7ms
# Speed: 1.0ms preprocess, 41.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Gate, 41.9ms
# Speed: 1.0ms preprocess, 41.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Gate, 30.2ms
# Speed: 1.1ms preprocess, 30.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Gate, 25.0ms
# Speed: 1.1ms preprocess, 25.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Gate, 26.0ms
# Speed: 1.0ms preprocess, 26.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Gate, 25.0ms
# Speed: 1.0ms preprocess, 25.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Gate, 27.3ms
# Speed: 1.0ms preprocess, 27.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Gate, 28.3ms
# Speed: 1.1ms preprocess, 28.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Gate, 25.5ms
# Speed: 0.9ms preprocess, 25.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Gate, 26.6ms
# Speed: 1.1ms preprocess, 26.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Gate, 22.2ms
# Speed: 1.0ms preprocess, 22.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Gate, 21.3ms
# Speed: 0.9ms preprocess, 21.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Gate, 21.3ms
# Speed: 1.1ms preprocess, 21.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Gate, 21.7ms
# Speed: 1.0ms preprocess, 21.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Gate, 21.4ms
# Speed: 1.0ms preprocess, 21.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Gate, 21.9ms
# Speed: 1.0ms preprocess, 21.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Gate, 21.8ms
# Speed: 1.1ms preprocess, 21.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Gate, 22.1ms
# Speed: 0.9ms preprocess, 22.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Gate, 21.9ms
# Speed: 0.9ms preprocess, 21.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Gate, 22.5ms
# Speed: 0.8ms preprocess, 22.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Gate, 22.6ms
# Speed: 0.9ms preprocess, 22.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Gate, 21.5ms
# Speed: 0.8ms preprocess, 21.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Gate, 21.6ms
# Speed: 0.9ms preprocess, 21.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Gate, 22.2ms
# Speed: 0.9ms preprocess, 22.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Gate, 21.3ms
# Speed: 1.1ms preprocess, 21.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Gate, 21.5ms
# Speed: 0.8ms preprocess, 21.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Gate, 25.5ms
# Speed: 0.9ms preprocess, 25.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Gate, 21.5ms
# Speed: 0.9ms preprocess, 21.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Gate, 22.7ms
# Speed: 0.9ms preprocess, 22.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Gate, 21.5ms
# Speed: 0.9ms preprocess, 21.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Gate, 21.7ms
# Speed: 0.9ms preprocess, 21.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Gate, 23.8ms
# Speed: 0.9ms preprocess, 23.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Gate, 21.0ms
# Speed: 0.9ms preprocess, 21.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Gate, 36.5ms
# Speed: 3.6ms preprocess, 36.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Gate, 20.8ms
# Speed: 0.9ms preprocess, 20.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Gate, 20.8ms
# Speed: 0.9ms preprocess, 20.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Gate, 21.7ms
# Speed: 1.0ms preprocess, 21.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Gate, 22.8ms
# Speed: 0.9ms preprocess, 22.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Gate, 22.4ms
# Speed: 0.9ms preprocess, 22.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Gate, 21.3ms
# Speed: 0.9ms preprocess, 21.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Gate, 21.6ms
# Speed: 0.9ms preprocess, 21.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Gate, 21.3ms
# Speed: 0.9ms preprocess, 21.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Gate, 22.0ms
# Speed: 0.9ms preprocess, 22.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Gate, 21.6ms
# Speed: 1.0ms preprocess, 21.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Gate, 21.4ms
# Speed: 0.9ms preprocess, 21.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Gate, 22.2ms
# Speed: 0.9ms preprocess, 22.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Gate, 31.2ms
# Speed: 0.9ms preprocess, 31.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Gate, 29.1ms
# Speed: 1.0ms preprocess, 29.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Gate, 30.2ms
# Speed: 1.0ms preprocess, 30.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Gate, 38.0ms
# Speed: 1.0ms preprocess, 38.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Gate, 37.1ms
# Speed: 1.1ms preprocess, 37.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Gate, 34.8ms
# Speed: 1.3ms preprocess, 34.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Gate, 29.8ms
# Speed: 1.3ms preprocess, 29.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Gate, 28.0ms
# Speed: 1.1ms preprocess, 28.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Gate, 26.8ms
# Speed: 0.9ms preprocess, 26.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Gate, 25.8ms
# Speed: 0.9ms preprocess, 25.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Gate, 26.1ms
# Speed: 0.9ms preprocess, 26.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Gate, 24.3ms
# Speed: 1.2ms preprocess, 24.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Gate, 22.3ms
# Speed: 0.9ms preprocess, 22.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Gate, 22.2ms
# Speed: 0.9ms preprocess, 22.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Gate, 21.5ms
# Speed: 0.9ms preprocess, 21.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Gate, 25.5ms
# Speed: 1.0ms preprocess, 25.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Gate, 25.1ms
# Speed: 1.0ms preprocess, 25.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Gate, 25.7ms
# Speed: 1.0ms preprocess, 25.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Gate, 20.8ms
# Speed: 0.9ms preprocess, 20.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Gate, 21.8ms
# Speed: 0.9ms preprocess, 21.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Gate, 22.1ms
# Speed: 0.8ms preprocess, 22.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Gate, 24.5ms
# Speed: 0.9ms preprocess, 24.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Gate, 22.0ms
# Speed: 0.9ms preprocess, 22.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Gate, 21.9ms
# Speed: 0.9ms preprocess, 21.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Gate, 21.2ms
# Speed: 0.9ms preprocess, 21.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Gate, 21.6ms
# Speed: 1.0ms preprocess, 21.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Gate, 21.9ms
# Speed: 0.9ms preprocess, 21.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Gate, 21.8ms
# Speed: 0.8ms preprocess, 21.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Gate, 21.0ms
# Speed: 0.9ms preprocess, 21.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Gate, 21.7ms
# Speed: 0.8ms preprocess, 21.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Gate, 21.5ms
# Speed: 0.9ms preprocess, 21.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Gate, 24.2ms
# Speed: 1.0ms preprocess, 24.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Gate, 21.9ms
# Speed: 0.8ms preprocess, 21.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Gate, 21.7ms
# Speed: 1.1ms preprocess, 21.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Gate, 21.8ms
# Speed: 0.9ms preprocess, 21.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Gate, 21.4ms
# Speed: 0.8ms preprocess, 21.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Gate, 21.1ms
# Speed: 0.9ms preprocess, 21.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Gate, 25.0ms
# Speed: 1.1ms preprocess, 25.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Gate, 23.0ms
# Speed: 0.9ms preprocess, 23.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Gate, 21.1ms
# Speed: 0.9ms preprocess, 21.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Gate, 21.7ms
# Speed: 1.1ms preprocess, 21.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Gate, 21.6ms
# Speed: 0.9ms preprocess, 21.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Gate, 21.4ms
# Speed: 0.8ms preprocess, 21.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Gate, 21.9ms
# Speed: 0.9ms preprocess, 21.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Gate, 21.9ms
# Speed: 0.9ms preprocess, 21.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Gate, 21.6ms
# Speed: 0.9ms preprocess, 21.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Gate, 21.4ms
# Speed: 0.8ms preprocess, 21.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Gate, 21.8ms
# Speed: 0.9ms preprocess, 21.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Gate, 25.5ms
# Speed: 1.0ms preprocess, 25.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Gate, 25.3ms
# Speed: 1.2ms preprocess, 25.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Gate, 25.0ms
# Speed: 0.9ms preprocess, 25.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Gate, 21.7ms
# Speed: 0.9ms preprocess, 21.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Gate, 22.1ms
# Speed: 0.9ms preprocess, 22.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Gate, 22.2ms
# Speed: 0.9ms preprocess, 22.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Gate, 22.0ms
# Speed: 0.9ms preprocess, 22.0ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Gate, 22.0ms
# Speed: 1.1ms preprocess, 22.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Gate, 22.0ms
# Speed: 0.8ms preprocess, 22.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Gate, 22.1ms
# Speed: 0.8ms preprocess, 22.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Gate, 22.2ms
# Speed: 0.9ms preprocess, 22.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Gate, 21.5ms
# Speed: 0.9ms preprocess, 21.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Gate, 21.8ms
# Speed: 0.9ms preprocess, 21.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Gate, 21.1ms
# Speed: 0.9ms preprocess, 21.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Gate, 22.3ms
# Speed: 0.9ms preprocess, 22.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Gate, 21.1ms
# Speed: 0.8ms preprocess, 21.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Gate, 21.3ms
# Speed: 0.8ms preprocess, 21.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Gate, 24.4ms
# Speed: 0.9ms preprocess, 24.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Gate, 23.9ms
# Speed: 0.9ms preprocess, 23.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Gate, 22.4ms
# Speed: 0.9ms preprocess, 22.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Gate, 21.8ms
# Speed: 0.9ms preprocess, 21.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Gate, 21.8ms
# Speed: 0.9ms preprocess, 21.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 21.2ms
# Speed: 0.9ms preprocess, 21.2ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 22.1ms
# Speed: 0.9ms preprocess, 22.1ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 21.5ms
# Speed: 0.9ms preprocess, 21.5ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 21.9ms
# Speed: 0.9ms preprocess, 21.9ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 22.0ms
# Speed: 0.9ms preprocess, 22.0ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 28.4ms
# Speed: 1.0ms preprocess, 28.4ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 28.7ms
# Speed: 1.1ms preprocess, 28.7ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 29.1ms
# Speed: 1.0ms preprocess, 29.1ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 28.9ms
# Speed: 1.0ms preprocess, 28.9ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 27.1ms
# Speed: 1.0ms preprocess, 27.1ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 25.5ms
# Speed: 1.0ms preprocess, 25.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 25.9ms
# Speed: 1.1ms preprocess, 25.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 29.5ms
# Speed: 0.9ms preprocess, 29.5ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 32.2ms
# Speed: 1.2ms preprocess, 32.2ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 26.9ms
# Speed: 2.0ms preprocess, 26.9ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 28.1ms
# Speed: 0.9ms preprocess, 28.1ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 22.5ms
# Speed: 0.9ms preprocess, 22.5ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 22.1ms
# Speed: 1.0ms preprocess, 22.1ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 21.7ms
# Speed: 0.9ms preprocess, 21.7ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 21.7ms
# Speed: 0.9ms preprocess, 21.7ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 23.2ms
# Speed: 0.9ms preprocess, 23.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 23.1ms
# Speed: 0.9ms preprocess, 23.1ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 22.3ms
# Speed: 0.9ms preprocess, 22.3ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 23.5ms
# Speed: 0.8ms preprocess, 23.5ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 21.7ms
# Speed: 1.2ms preprocess, 21.7ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 21.5ms
# Speed: 0.8ms preprocess, 21.5ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 22.2ms
# Speed: 0.9ms preprocess, 22.2ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 21.4ms
# Speed: 0.9ms preprocess, 21.4ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 21.8ms
# Speed: 0.8ms preprocess, 21.8ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 22.0ms
# Speed: 1.0ms preprocess, 22.0ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 21.6ms
# Speed: 0.9ms preprocess, 21.6ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 22.4ms
# Speed: 1.1ms preprocess, 22.4ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 21.9ms
# Speed: 1.0ms preprocess, 21.9ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 21.2ms
# Speed: 0.9ms preprocess, 21.2ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 21.9ms
# Speed: 1.2ms preprocess, 21.9ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 21.8ms
# Speed: 0.8ms preprocess, 21.8ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 22.1ms
# Speed: 0.9ms preprocess, 22.1ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
# Video inference completed. Saved at: /Users/mohammadbilal/Documents/Projects/GateDetection/assets/results/output_yolo8n.mp4
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
